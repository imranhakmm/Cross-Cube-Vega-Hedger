# %% [markdown]
# # Market-Maker P&L Attribution
#
# Run a small market-making experiment and inspect reconciled attribution.

# %%
from cxvega.config import load_settings
from cxvega.market_maker import run_market_maker_simulation
from cxvega.simulator import simulate_cube_path

settings = load_settings('../configs/default.yaml', {'market_maker': {'n_paths': 4, 'days': 12}})
path = simulate_cube_path(settings, n_steps=12)
result = run_market_maker_simulation(settings, path)
result.summary
