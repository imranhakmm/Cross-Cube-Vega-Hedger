# %% [markdown]
# # Cube Simulator Walkthrough
#
# This notebook sketches the deterministic simulator entry point used by the build pipeline.

# %%
from cxvega.config import load_settings
from cxvega.simulator import simulate_cube_path

settings = load_settings('../configs/default.yaml')
path = simulate_cube_path(settings, n_steps=16)
path.vols.shape
